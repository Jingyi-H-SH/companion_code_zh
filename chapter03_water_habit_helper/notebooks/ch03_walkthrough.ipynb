# %% [markdown]
# # 第3章 饮水习惯助手快速演示

# %%
from pathlib import Path
import pandas as pd

ROOT = Path("..").resolve()
pd.read_csv(ROOT / "data" / "water_habit_log.csv").head()

# %%
# !python ../run_demo.py

# %%
pd.read_csv(ROOT / "outputs" / "suggestions.csv")
