# %% [markdown]
# # 第2章 留言文本挖掘快速演示

# %% [markdown]
# ## 讲解定位
#
# 这个 notebook 适合在第 2 章上课时快速演示“数据读取 -> 运行流程 -> 查看结果”的最短路径。

# %%
from pathlib import Path
import pandas as pd

ROOT = Path("..").resolve()
pd.read_csv(ROOT / "data" / "sample_messages.csv").head()

# %%
# !python ../run_demo.py

# %%
pd.read_csv(ROOT / "outputs" / "message_predictions.csv")[["message_id", "predicted_topic", "predicted_sentiment"]].head(10)
